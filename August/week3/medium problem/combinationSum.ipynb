# %%
#index = 0

class Solution:
    #choosed = []
    #index2 = [0]
    #index = 0
    
    def __init__(self):
        self.test = 123
    
    def combinationSum(self, candidates: List[int], target: int) -> List[List[int]]:
        #global choosed
        #choosed = [1]*len(candidates)
        #global index
        #print("choosed:%s"%(choosed))
        #index = 0
        candidates.sort()
        print('test:%d' % (self.test))
        
        output = []
        temp = []
        self.findcombine(candidates, target, temp, output)
        #index = 0
        return output
        
    def findcombine(self, candidates, target, temp, output):
        #global choosed
        #global index2
        #global index
                
        if target == 0:  # terminate condition
            compare = sorted(temp[:])
            
            for i in range(len(output)):
                if output[i] == compare:
                    return
            output.append(temp[:])
            
#             if Solution.index != 0:
#                 compare = sorted(temp[:])
#                 if output[Solution.index - 1] != compare:
#                     output.append(temp[:])
#                     Solution.index = Solution.index + 1
#             else:    
#                 output.append(temp[:])
#                 Solution.index = Solution.index + 1
            
            print(output)
            return
        
        for i in range(len(candidates)):
            # constraint condition
            #if choosed[i] == 1:            
            if candidates[i] <= target:
                temp.append(candidates[i])
                self.findcombine(candidates, target - candidates[i], temp, output)
                temp.pop()

            if candidates[i] > target:
                return
            
#             if index == 0:
#                 choosed[i] = 0
            #index = index + 1
